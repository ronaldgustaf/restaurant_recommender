# %%
import json
import pandas as pd

# %%
# %%time
review_file = 'dataset/yelp_academic_dataset_review.json'
business_file = 'dataset/yelp_academic_dataset_business.json'

# load json file
restaurant_json = [json.loads(line) for line in open(business_file, 'r', encoding='UTF-8')]
# Out:
# CPU times: user 2.23 s, sys: 423 ms, total: 2.65 s
# Wall time: 3.42 s

# %%
restaurant_df = pd.DataFrame(restaurant_json)

# %%
philly_df = pd.read_csv('vader_sent_filtered_philly_295k.csv')

# %%
philly_df = philly_df[['business_id','business_id_cat']]

# %%
philly_df = philly_df.drop_duplicates()

# %%
final = pd.merge(philly_df,restaurant_df, on='business_id', how='inner')

# %%
final
# Out:
#                  business_id  business_id_cat                          name  \
# 0     kxX2SOes4o-D3ZQBkiMRfA                0                         Zaika
# 1     AmI3LIUNwsi4023hOVGu3w             1342                       Moshulu
# 2     wGnBaLvgH3hrq6C3AnO5Mg             2065            Shish-Kabob Palace
# 3     fYSaoJMOj7-r4XWEuYjRxw             2500                  Bleu Martini
# 4     mXNKjKkq7Zk6-39_t4c5OA             2765   Spice Garden Indian Cuisine
# ...                      ...              ...                           ...
# 5790  WQ1m-h4N3UoSwKFHa5zAwg             3328                   Nineteen 26
# 5791  NWLViuVGh--12IAL1iw2pQ             1756             The Shake Seafood
# 5792  2MKTSjcis749QGzm0vwFXw             1136             MiXXed Breed Cafe
# 5793  WZfyxxWi6ZiperQ1Hfy_bQ             4402  Adrianas Breakfast and Lunch
# 5794  I2Yt2mJp0TJkdOnIpuOwew             3307                Tres Jalapenos
#
#                   address          city state postal_code   latitude  \
# 0          2481 Grant Ave  Philadelphia    PA       19114  40.079848
# 1     401 S Columbus Blvd  Philadelphia    PA       19106  39.942335
# 2          1683 Grant Ave  Philadelphia    PA       19115  40.086533
# 3             24 S 2nd St  Philadelphia    PA       19106  39.949376
# 4     11728 Bustleton Ave  Philadelphia    PA       19116  40.119785
# ...                   ...           ...   ...         ...        ...
# 5790      21 N Juniper St  Philadelphia    PA       19107  39.953035
# 5791  5717 Rising Sun Ave  Philadelphia    PA       19120  40.041642
# 5792      1631 Wallace St  Philadelphia    PA       19130  39.965909
# 5793        1717 S 2nd St  Philadelphia    PA       19148  39.926249
# 5794     744 Christian St  Philadelphia    PA       19147  39.938423
#
#       longitude  stars  review_count  is_open  \
# 0    -75.025080    4.0           181        1
# 1    -75.141308    3.5           874        1
# 2    -75.039017    3.5            93        1
# 3    -75.143886    2.5           215        1
# 4    -75.018028    4.0             9        0
# ...         ...    ...           ...      ...
# 5790 -75.162063    3.0            16        1
# 5791 -75.105872    4.5             8        1
# 5792 -75.165505    2.0             8        0
# 5793 -75.149285    3.5             6        0
# 5794 -75.156159    3.0             5        1
#
#                                              attributes  \
# 0     {'Caters': 'True', 'Ambience': '{'romantic': F...
# 1     {'RestaurantsPriceRange2': '3', 'Alcohol': ''f...
# 2     {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 3     {'BusinessAcceptsCreditCards': 'True', 'Alcoho...
# 4     {'Caters': 'True', 'GoodForKids': 'True', 'Bik...
# ...                                                 ...
# 5790  {'BikeParking': 'False', 'RestaurantsPriceRang...
# 5791  {'BusinessParking': '{'garage': False, 'street...
# 5792  {'BusinessParking': '{'garage': False, 'street...
# 5793  {'GoodForKids': 'True', 'RestaurantsPriceRange...
# 5794               {'RestaurantsGoodForGroups': 'True'}
#
#                                              categories  \
# 0                 Halal, Pakistani, Restaurants, Indian
# 1     American (Traditional), Seafood, Nightlife, Ev...
# 2           Uzbek, Restaurants, Middle Eastern, Russian
# 3     Hookah Bars, Bars, Nightlife, Restaurants, Asi...
# 4     Indian, Restaurants, Caterers, Event Planning ...
# ...                                                 ...
# 5790                        American (New), Restaurants
# 5791                 Seafood, Cajun/Creole, Restaurants
# 5792             Restaurants, Cafes, Food, Coffee & Tea
# 5793                     Delis, Restaurants, Sandwiches
# 5794                               Restaurants, Mexican
#
#                                                   hours
# 0     {'Tuesday': '11:0-21:0', 'Wednesday': '11:0-21...
# 1     {'Monday': '0:0-0:0', 'Tuesday': '16:0-21:0', ...
# 2     {'Tuesday': '11:0-22:0', 'Wednesday': '11:0-22...
# 3     {'Monday': '16:0-2:0', 'Tuesday': '16:0-2:0', ...
# 4     {'Tuesday': '11:0-21:0', 'Wednesday': '11:0-21...
# ...                                                 ...
# 5790                                               None
# 5791  {'Monday': '0:0-0:0', 'Tuesday': '13:0-21:0', ...
# 5792  {'Monday': '7:0-16:0', 'Tuesday': '8:0-15:0', ...
# 5793                                               None
# 5794                                               None
#
# [5795 rows x 15 columns]
